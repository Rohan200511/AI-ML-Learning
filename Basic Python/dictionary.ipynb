# %%
Student = {
    "Name" : "Rohan",
    "City" : "Gurugram",
    "Age" : 20,
    "College" : "GLBITM"
}

print(Student)
print(type(Student))
print(Student["Age"])
Student["City"] = "Greater Noida"
print(Student)
# Out:
# {'Name': 'Rohan', 'City': 'Gurugram', 'Age': 20, 'College': 'GLBITM'}
# <class 'dict'>
# 20
# {'Name': 'Rohan', 'City': 'Greater Noida', 'Age': 20, 'College': 'GLBITM'}
