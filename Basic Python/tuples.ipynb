# %%
myTuple = ("hello" , "My" , "Name" , "Is" , "Rohan")
print(myTuple)
# Out:
# ('hello', 'My', 'Name', 'Is', 'Rohan')

# %%
singleTuple = (1)
print(type(singleTuple))

emptyTuple = ()
print(type(emptyTuple))

singleTuple2 = (1, )
print(type(singleTuple2))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'tuple'>

# %%
name = ("Divya" , "Neha" , "Tanya" , "Suhani" , "Divya" , "Khushi" , "Janvi")
print(name.index("Divya"))
print(name.count("Khushi"))
print(name.count("Divya"))
print(name.count("Rohan"))
# Out:
# 0
# 1
# 2
# 0

# %%
print(min(name))
print(max(name))
# Out:
# Divya
# Tanya
