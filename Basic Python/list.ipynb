# %%
food = ["Chole Bathure" , "Chocolate" , "Chips" , "Waffle"]
print(food)
# Out:
# ['Chole Bathure', 'Chocolate', 'Chips', 'Waffle']

# %%
print(len(food))
# Out:
# 4

# %%
food.append(4)
print(food)
# Out:
# ['Chole Bathure', 'Chocolate', 'Chips', 'Waffle', 4]

# %%
marks = [85 , 89 , 96 , 100 , 93]

print(marks[2])

marks[2] = 45

print(marks[2])
# Out:
# 96
# 45

# %%
print(marks[1:4])
print(food[::-1])
print(marks[::-2])
# Out:
# [89, 45, 100]
# [4, 'Waffle', 'Chips', 'Chocolate', 'Chole Bathure']
# [93, 45, 85]

# %%
st_food = ["Chole Bathure" , "Chocolate" , "Chips" , "Waffle"]

st_food.append("Rajma Chawal")
st_food.remove("Waffle")
st_food.pop(0)
st_food.insert(5 , "Hi")
print(st_food)

st_food.sort()
# Out:
# ['Chocolate', 'Chips', 'Rajma Chawal', 'Hi']

# %%
print(type(st_food))
# Out:
# <class 'list'>

# %%
list = []

for x in range(2):
    x = (input("Enter: "))
    list.append(x)
    
print(list)
# Out:
# ['Hi', '7']
# 7

# %%
for item in food:
    print(item)
# Out:
# Chole Bathure
# Chocolate
# Chips
# Waffle
# 4

# %%
i = 0
while len(food) and i < len(food):
    print(food[i])
    i += 1
# Out:
# Chole Bathure
# Chocolate
# Chips
# Waffle
# 4

# %%
#---------------------------------------------- LIST COMPREHENSION---------------------------------------

# %%
my_list = [x for x in range(10 , 60 , 10)]
print(my_list)
# Out:
# [10, 20, 30, 40, 50]

# %%
squares = [x * x for x in my_list]
print(squares)
# Out:
# [100, 400, 900, 1600, 2500]
