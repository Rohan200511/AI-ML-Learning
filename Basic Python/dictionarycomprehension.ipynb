# %%
numbers = {x : x * x for x in range(7)}
print(numbers)
numbers = {x : x * x * x for x in range(7)}
print(numbers)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216}

# %%
words = ["apple","cat","python"]

length = {word : len(word) for word in words}
print(length)
# Out:
# {'apple': 5, 'cat': 3, 'python': 6}

# %%
wordss = ['a' , 'b' , 'c']
ascii_dict = {x : ord(x) for x in wordss}
print(ascii_dict)
# Out:
# {'a': 97, 'b': 98, 'c': 99}
