# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
X = df.drop("species" , axis = 1)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors = 13)

# %%
model_knn.fit(X_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(X_test , y_test)
# Out:
# 1.0

# %% [markdown]
# #Overfitting when the accuracy is above 95%

# %%
#SVM
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma = 'auto')
model_svm.fit(X_train, y_train)
model_svm.score(X_test , y_test)
# Out:
# 1.0

# %% [markdown]
# # ON CHANGING DIFFERENT PARAMETERS OF MODELS WE ARE GETTING DIFFERENT SCORES. SO NOW LET'S TRY HYPERPARAMETER TUNING

# %% [markdown]
# # Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm) , {
    'C' : [1 , 10 , 20 , 30],
    'kernel' : ['rbf' , 'linear']
} , cv = 5 , return_train_score=False)

# %%
classifier.fit(X , y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
results = pd.DataFrame(classifier.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.007330      0.003441         0.001952        0.001649       1
# 1       0.002819      0.003042         0.004148        0.004801       1
# 2       0.003064      0.002935         0.003805        0.002462      10
# 3       0.004219      0.003644         0.001812        0.003624      10
# 4       0.003021      0.006043         0.000000        0.000000      20
# 5       0.003019      0.002700         0.005525        0.005205      20
# 6       0.002820      0.000753         0.002488        0.000955      30
# 7       0.003082      0.006165         0.000829        0.001657      30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 6          rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
# 7       linear  {'C': 30, 'kernel': 'linear'}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
# 5                1.0           0.900000           0.933333                1.0
# 6                1.0           0.900000           0.933333                1.0
# 7                1.0           0.900000           0.900000                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5
# 5         0.966667        0.042164                6
# 6         0.960000        0.038873                7
# 7         0.960000        0.048990                7

# %%
results[['param_C' , 'param_kernel' , 'mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.980000
# 1       1       linear         0.980000
# 2      10          rbf         0.980000
# 3      10       linear         0.973333
# 4      20          rbf         0.966667
# 5      20       linear         0.966667
# 6      30          rbf         0.960000
# 7      30       linear         0.960000

# %% [markdown]
# # RANDOM SEARCH CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r = RandomizedSearchCV((model_svm) , {
    'C' : [1 , 10 , 20 , 30],
    'kernel' : ['rbf' , 'linear']
} , n_iter = 4 , cv = 5 , return_train_score=False)

# %%
classifier_r.fit(X , y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
results = pd.DataFrame(classifier_r.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.007776      0.002542         0.001822        0.002006          rbf
# 1       0.002429      0.002284         0.003046        0.004178       linear
# 2       0.005565      0.003147         0.002084        0.002636          rbf
# 3       0.000863      0.001178         0.004329        0.003936          rbf
#
#   param_C                         params  split0_test_score  \
# 0      20     {'kernel': 'rbf', 'C': 20}           0.966667
# 1      20  {'kernel': 'linear', 'C': 20}           1.000000
# 2       1      {'kernel': 'rbf', 'C': 1}           0.966667
# 3      10     {'kernel': 'rbf', 'C': 10}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.900000           0.966667                1.0
# 1                1.0           0.900000           0.933333                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.966667           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.036515                3
# 1         0.966667        0.042164                4
# 2         0.980000        0.016330                1
# 3         0.980000        0.016330                1

# %%
results[['param_C' , 'param_kernel' , 'mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0      20          rbf         0.966667
# 1      20       linear         0.966667
# 2       1          rbf         0.980000
# 3      10          rbf         0.980000
