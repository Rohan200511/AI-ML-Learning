# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, SimpleRNN, Dense

# %%
sentences = [
 "I love this product",
 "This movie made me smile",
 "Service was friendly and quick",
 "Today felt bright and happy",
 "This is the best day",
 "Absolutely fantastic experience",
 "I enjoyed every single moment",
 "Great job, well done",
 "The food tasted delicious",
 "Totally recommend to everyone",
 "Very satisfied with results",
 "This worked better than expected",
 "Amazing quality and value",
 "Such a pleasant surprise",
 "I feel positive about this",
 "I hate this product",
 "This movie bored me",
 "Service was rude and slow",
 "Today was cold and lonely",
 "This is the worst day",
 "Terrible experience overall",
 "I regret buying this",
 "Very disappointed with results",
 "The food tasted awful",
 "Do not recommend this",
 "It broke after one use",
 "Not worth the money",
 "Utterly frustrating and annoying",
 "I feel negative about this",
 "Such a waste of time",
]
labels = [1]*15 + [0]*15
labels = np.array(labels)

# %%
vocab_size = 2000
tokenizer = Tokenizer(num_words=vocab_size , oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)

# %%
seqs = tokenizer.texts_to_sequences(sentences)
maxLen = max(len(s) for s in seqs)
X = pad_sequences(seqs , maxlen=maxLen , padding='post')
y = labels

# %%
maxLen
# Out:
# 5

# %%
X[0]
# Out:
# array([ 3, 26,  2,  7,  0])

# %%
embed_dim = 16
rnn_units = 8

# %%
inp = Input(shape=(maxLen,), dtype="int32", name='input')
x = Embedding(input_dim=vocab_size , output_dim=embed_dim, mask_zero=True, name = 'embed')(inp)

rnn = SimpleRNN(units=rnn_units,  name = 'simple_rnn')
x_last = rnn(x)
out = Dense(1 , activation='sigmoid', name = 'out')(x_last)
model = Model(inputs = inp , outputs = out)
model.compile(optimizer='adam' , loss='binary_crossentropy' , metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 5)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embed (Embedding)   │ (None, 5, 16)     │     32,000 │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_4         │ (None, 5)         │          0 │ input[0][0]       │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ simple_rnn          │ (None, 8)         │        200 │ embed[0][0],      │
# │ (SimpleRNN)         │                   │            │ not_equal_4[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out (Dense)         │ (None, 1)         │          9 │ simple_rnn[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 32,209 (125.82 KB)
#  Trainable params: 32,209 (125.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X , y , epochs=25 , batch_size=8, verbose=1)
# Out:
# Epoch 1/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5333 - loss: 0.6910
# Epoch 2/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6667 - loss: 0.6791
# Epoch 3/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7667 - loss: 0.6686
# Epoch 4/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - loss: 0.6587
# Epoch 5/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - loss: 0.6483
# Epoch 6/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8333 - loss: 0.6379
# Epoch 7/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.6254
# Epoch 8/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8333 - loss: 0.6133
# Epoch 9/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8667 - loss: 0.6002
# Epoch 10/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8667 - loss: 0.5861
# Epoch 11/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9333 - loss: 0.5713
# Epoch 12/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9333 - loss: 0.5553
# Epoch 13/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9333 - loss: 0.5386
# Epoch 14/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9333 - loss: 0.5211
# Epoch 15/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9333 - loss: 0.5027
# Epoch 16/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9333 - loss: 0.4849
# Epoch 17/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9333 - loss: 0.4648
# Epoch 18/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9333 - loss: 0.4452
# Epoch 19/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.4249
# Epoch 20/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.4049
# Epoch 21/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.3842
# Epoch 22/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.3642
# Epoch 23/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.3451
# Epoch 24/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.3265
# Epoch 25/25
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.3081
